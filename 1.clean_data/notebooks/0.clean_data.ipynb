# %%
import pathlib

import numpy as np
import pandas as pd

# %%
# set the path to the data
academic_data_path = pathlib.Path(
    "../../data/All_academic_projects_funded_by_NIH_.xlsx"
).resolve(strict=True)
output_data_path = pathlib.Path(
    "../../data/All_academic_projects_funded_by_NIH_cleaned.parquet"
).resolve()
# get the sheet names in the excel file
academic_data = pd.read_excel(academic_data_path, sheet_name="#205C")
print(academic_data.shape)
academic_data.head()
# Out:
# (1006, 7)
# /Users/mike/miniconda3/envs/NIH_env/lib/python3.12/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#   Table #205-C: Research Project Grants and Other Mechanisms - Competing Applications, Awards, Success Rates and Total Funding  by NIH Institutes/Centers, Grant Mechanisms and Activity Codes, Fiscal Year 2023  \
# 0  Made with Direct Budget Authority, Superfund F...
# 1                                   Institute/Center
# 2                                                NCI
# 3                                                NCI
# 4                                                NCI
#
#                  Unnamed: 1     Unnamed: 2                       Unnamed: 3  \
# 0                       NaN            NaN                              NaN
# 1  Mechanism/Funding Source  Activity Code  Number of Applications Reviewed
# 2              RPG - Direct            P01                               89
# 3              RPG - Direct            R00                                1
# 4              RPG - Direct            R01                             5442
#
#                        Unnamed: 4    Unnamed: 5     Unnamed: 6
# 0                             NaN           NaN            NaN
# 1  Number of Applications Awarded  Success Rate  Total Funding
# 2                              17      0.191011       41733718
# 3                               1             1         783430
# 4                             793      0.145718      437729824

# %%
# drop the first row and the column names
academic_data = academic_data.drop(0)
academic_data.columns = academic_data.iloc[0]
academic_data = academic_data.drop(1)
print(academic_data.shape)
academic_data.head()
# Out:
# (1004, 7)
# 1 Institute/Center Mechanism/Funding Source Activity Code  \
# 2              NCI             RPG - Direct           P01
# 3              NCI             RPG - Direct           R00
# 4              NCI             RPG - Direct           R01
# 5              NCI             RPG - Direct           R03
# 6              NCI             RPG - Direct           R15
#
# 1 Number of Applications Reviewed Number of Applications Awarded Success Rate  \
# 2                              89                             17     0.191011
# 3                               1                              1            1
# 4                            5442                            793     0.145718
# 5                             369                             50     0.135501
# 6                             138                             20     0.144928
#
# 1 Total Funding
# 2      41733718
# 3        783430
# 4     437729824
# 5       4817701
# 6       8818798

# %%
# drop activity codes that equal to 'Total'
academic_data = academic_data[academic_data["Activity Code"] != "Total"]
print(academic_data.shape)
# Out:
# (909, 7)

# %%
# move the Activity Code to the first column
academic_data.insert(0, "Activity Code", academic_data.pop("Activity Code"))
academic_data.head()
# Out:
# 1 Activity Code Institute/Center Mechanism/Funding Source  \
# 2           P01              NCI             RPG - Direct
# 3           R00              NCI             RPG - Direct
# 4           R01              NCI             RPG - Direct
# 5           R03              NCI             RPG - Direct
# 6           R15              NCI             RPG - Direct
#
# 1 Number of Applications Reviewed Number of Applications Awarded Success Rate  \
# 2                              89                             17     0.191011
# 3                               1                              1            1
# 4                            5442                            793     0.145718
# 5                             369                             50     0.135501
# 6                             138                             20     0.144928
#
# 1 Total Funding
# 2      41733718
# 3        783430
# 4     437729824
# 5       4817701
# 6       8818798

# %%
academic_data["Mechanism/Funding Source"].value_counts()
# Out:
# Mechanism/Funding Source
# Other Mechanisms - Direct                                         594
# RPG - Direct                                                      282
# RPG - Reimbursable                                                 12
# Other Mechanisms - Reimbursable                                     7
# Direct Authorization - Type 1 Diabetes Other Activities             5
# Other Mechanisms - Superfund                                        4
# Direct Authorization - Type 1 Diabetes Research Project Grants      3
# RPG - Superfund                                                     2
# Name: count, dtype: int64

# %%
# keep only the Other Mechanisms - Direct and RPG - Direct for mechanisms
academic_data = academic_data[
    academic_data["Mechanism/Funding Source"].isin(
        ["Other Mechanisms - Direct", "RPG - Direct"]
    )
]
print(academic_data.shape)
academic_data.head()
# Out:
# (876, 7)
# 1 Activity Code Institute/Center Mechanism/Funding Source  \
# 2           P01              NCI             RPG - Direct
# 3           R00              NCI             RPG - Direct
# 4           R01              NCI             RPG - Direct
# 5           R03              NCI             RPG - Direct
# 6           R15              NCI             RPG - Direct
#
# 1 Number of Applications Reviewed Number of Applications Awarded Success Rate  \
# 2                              89                             17     0.191011
# 3                               1                              1            1
# 4                            5442                            793     0.145718
# 5                             369                             50     0.135501
# 6                             138                             20     0.144928
#
# 1 Total Funding
# 2      41733718
# 3        783430
# 4     437729824
# 5       4817701
# 6       8818798

# %%
# remove OD COMMON FUND, FIC, OD ORIP
academic_data = academic_data[
    ~academic_data["Institute/Center"].isin(["OD COMMON FUND", "FIC", "OD ORIP"])
]
print(academic_data.shape)
academic_data.head()
# Out:
# (828, 7)
# 1 Activity Code Institute/Center Mechanism/Funding Source  \
# 2           P01              NCI             RPG - Direct
# 3           R00              NCI             RPG - Direct
# 4           R01              NCI             RPG - Direct
# 5           R03              NCI             RPG - Direct
# 6           R15              NCI             RPG - Direct
#
# 1 Number of Applications Reviewed Number of Applications Awarded Success Rate  \
# 2                              89                             17     0.191011
# 3                               1                              1            1
# 4                            5442                            793     0.145718
# 5                             369                             50     0.135501
# 6                             138                             20     0.144928
#
# 1 Total Funding
# 2      41733718
# 3        783430
# 4     437729824
# 5       4817701
# 6       8818798

# %%
# write the cleaned data to a parquet file
academic_data.to_parquet(output_data_path, index=False)
